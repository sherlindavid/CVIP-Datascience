# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("globalterrorism.csv",encoding='latin-1')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
date_cols = ['approxdate', 'resolution']
for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# %%
missing_values=df.isnull().sum()

# %%
# Distribution of Terrorist Attacks across Regions and Countries
plt.figure(figsize=(12, 6))
sns.countplot(x='region_txt', data=df, order=df['region_txt'].value_counts().index)
plt.title('Distribution of Terrorist Attacks across Regions')
plt.xlabel('Region')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
top_countries = df['country_txt'].value_counts().nlargest(10)
sns.barplot(x=top_countries.index, y=top_countries.values)
plt.title('Top 10 Most Targeted Countries')
plt.xlabel('Country')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=45)
plt.show()

# %%
# Trend of Terrorist Attacks Over the Years
plt.figure(figsize=(12, 6))
df['year'] = df['iyear'] + df['imonth'] / 12  # Combine year and month for better time representation
sns.lineplot(x='year', y='iyear', data=df)
plt.title('Trend of Terrorist Attacks Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.show()

# %%
# Most Common Attack Types
plt.figure(figsize=(12, 6))
sns.countplot(x='attacktype1_txt', data=df, order=df['attacktype1_txt'].value_counts().index)
plt.title('Most Common Attack Types')
plt.xlabel('Attack Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Casualties and Injuries Analysis
plt.figure(figsize=(12, 6))
sns.scatterplot(x='nkill', y='nwound', data=df, hue='attacktype1_txt', palette='viridis', size='nkill')
plt.title('Casualties and Injuries Analysis')
plt.xlabel('Number of Killed')
plt.ylabel('Number of Wounded')
plt.legend(title='Attack Type', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Analysis of Specific Terrorist Groups
plt.figure(figsize=(12, 6))
top_terrorist_groups = df['gname'].value_counts().nlargest(10)
sns.barplot(x=top_terrorist_groups.index, y=top_terrorist_groups.values, palette='Set2')
plt.title('Top 10 Most Active Terrorist Groups')
plt.xlabel('Terrorist Group')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=45)
plt.show()

# %%
# Correlation Analysis
correlation_matrix = df.corr()

# Display Correlation Matrix as a Table
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#            eventid     iyear    imonth      iday  extended   country  \
# eventid   1.000000  0.999996  0.002706  0.018336  0.091761 -0.135039
# iyear     0.999996  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth    0.002706  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday      0.018336  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended  0.091761  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...            ...       ...       ...       ...       ...       ...
# INT_LOG  -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO -0.133252 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC -0.077852 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY  -0.175605 -0.175596 -0.006336 -0.001199  0.080767  0.153118
# year      0.999824  0.999773  0.021429  0.018367  0.091723 -0.135126
#
#             region  latitude  longitude  specificity  ...  ransomamtus  \
# ...

# %%
# Statistical Analysis
# Example: Hypothesis Testing
from scipy.stats import ttest_ind
# Hypothesis: Is there a significant difference in the number of killed between successful and unsuccessful attacks?
successful_attacks = df[df['success'] == 1]['nkill']
unsuccessful_attacks = df[df['success'] == 0]['nkill']
t_statistic, p_value = ttest_ind(successful_attacks.dropna(), unsuccessful_attacks.dropna(), equal_var=False)
print(f"T-Statistic: {t_statistic}, p-value: {p_value}")
# Out:
# T-Statistic: 48.19016546216014, p-value: 0.0
